# %%
#Installation
# !pip install -q git+https://github.com/openai/whisper.git
# !pip install -q gradio
# !pip install -q pyChatGPT
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.9 MB/s eta 0:00:00
# ...

# %%
#Imports
import whisper
import gradio as gr
import time
from pyChatGPT import ChatGPT
import warnings
# Out:
# /usr/local/lib/python3.10/dist-packages/trio/_core/_multierror.py:406: RuntimeWarning: IPython detected, but you already have a custom exception handler installed. I'll skip installing Trio's custom handler, but this means exception groups will not show full tracebacks.
#   warnings.warn(

# %%
#Defining Variables
import warnings
import whisper

warnings.filterwarnings("ignore")

secret_token = "eyJhbGciOiJkaXIiLCJlbmMiOiJBMjU2R0NNIn0..M1ZkfZZ9qgzvS94z.aF-otabmuR1-9zT-s8EmrBcD2cbC_h9PKP0Cot9NdinE1jQD0uWdGXQJdjOmTtBGftHpR7hOw4sZ6GKIx_u635cPKWGjAj7aCWf2t_Lm3R7E_4GocdavjVGJ5VyHlEM07xt3l43g-uuCK-ZaVqeeNbMLMk1MKsgnRWlicDphIWmBFpcq9ct-eqaQdEbM_OoQl342S2jqX3uVGvUdM1-76Z8Gq25gPs-3pXwMosi_hwTNFnIK5GdNDiZqBrgoldfEqDhYgHB1RAEpbD5d-abUvAfdiEV74CysX7zWBf1eCygIJ-f7DVEFLdJCKNBh46h8KqtCFogvYCOzrJ5YhVqr8SEsd1YRfEl_xh9FV7qgJ8s2gLdrKvhbw4GjTGRvYZUmRbt4OhXUFpfdMpgeFAYB25Rta3EwH10FDnLQwOHs-UvrNL_zmslQjuAec4eKkDl84FFP_W5UIdu5waHaXjWmcQ6yRodObYDKE3fiSF-2Ui5gbRbSUtHetIC6xI894ddw4zhcN2n7eIp91Yw5cgFHHOSGyeTmMjtdmkNzc5nwIyfohkfZI-esCuvOPnAmHndb29emkGofiahnHYDTbu5CNb69Lr59yLDXjrQmggte7C0vSLpyJiSsZb0dIyEmjO3PcQ744JdmBGGwmfzLa4qxI7PdyA7sUqpgnZ7-eTzNBkU3mB-Csp9r3z2sAK9ejg_H4ihLpzsMWIMmpRx4rlm9AIy9WNJieNbAuHNpC39WFF9lHg97jUOb20IBuQ6up7L8iaCvlsicQkiF5uDljoQO4iVbJ9dnDQ1b7SUt5r_PRxQJE1mEDdIQGosUucQGwW82S3l3p3UgRCvl313QiP1Fac6WbpogURtFCG6rOnwYUmQfaaoS1kIKsTnta32_m1-TIcDlBes8bz6_09AvIr4cioNyctsCrf90GXvddCsLQConXYV3bP8IW0H2vcYLL0cns1uOdYMr5r08A5zhyqDcBYjiqxxB2xshvhQgUzyAeEq4Gjrx7oNvn7vQ2BT6Vf4xIhNcXIsUPW7HWGWl98Km5kLzkHGba8tKLETaY9gWYNAb_r1jpeU_W-FU5J38h0dqRefKdcDf6VpQ823rM7V6ZiWWwI2-lRdj3hfIoXC0HY1svit3zAa-J5zPGLXJQrgmeKzQAsO4mRIqFWRwzufvwL1Dew7RTe2-89BSis2aIlJIEfNxAWij3Wfd3EVblZ4HAkA1tFqv13mJHQkTuyFceCwSBBMOI6zPHdtCwcVzodrFVQgUxCeCe9NvcdVbah23Gs528gxGk4ga00Ksg_1fpelNDfl0CuPO4PoODZ2MbcF4m8GnLAnwDeVMbU8bo-3Z_u0Z7LzdvAPKv3q7wp_DUZ-fGjjZqc3LAdsXXbpMrovvt8rXwqTqri0Gt6GRaVqMV9Urpi_MaJ9bq6ckaXD1ESg7QRGwB8Rz4F31W_ZC5Yrt1fr2wqVp-T0X-7Yyu7aKrH0t7LCyXmLcspPNlH4Ns-tgHxeWQuhU4qWivSCuc48SMBwZ5bHAdjufNvhJadKQ9enTWv9eWOOLqqcPW8RyBFCYjZyL6oUOZi6ICzIiOXSbP0oc4ZQvwrjnx6j6V0y7XUEkUzYsvpj2_mWhnTGlDCGLoHj4wcnQoLZCJG4QKx0d9D-KvW4yngQULK_XC1MvyiMUAOjwHZLdAMvy-5joMhpcuCrJB5t_xjvWfltybSwR8XakQ02tEQ5xmbezCJilcQXVYXFdkoTqjqQFcd9xl13hgXUmpT1lieheitP2RBZGfrLE3skeQ4Drfzv2a2miw6fAMshrruMS03IWHRPfYdiRB4D-oXyoGxAjAR4HVJ9Pcoieb50WA0YcAxy7rdXyyfW0ozPE-vlSoNQOY8zcFDKC23AoLFmv7nDsRdTplYj5R7rThxjq0KXT9D2JOT0BC0zD_G0shtzvi61imW9qLuF_DcBi-1GehDc347mvEibLYBpIUanwGhyOEICnwOFbrxVBAfm1K21pL4XlDR57N1FVBHe-I-wFJ8_mVS4wrpXE9qMGxftg6QEqYQv1O69s8vtBUUsJMHW_r677zjXT3YZpQg7bkOfGNnzy1IUkwxQB1Zi5eVKqQNMv_FFHqG8WHRVBJm-4II4914gkWQUUHdf-1FEzJpH5GyeLp1VTZPnetzTWjNBlk_kCRHklNt7e8qKwH2eS0xFvDwqAYgTm8p874ZjXNp7tEbT3kGQM07vzXclsvbM838o1n4h_v5htSBEDOS8EJn_m3xQYLD8LM0LysERp78B69E7tgO9CrcWKw6r5Joe3azQh-DHxVXfJUUuwP-VoQsGU4hA_FoBjFLGmaHTAZiZPS3-OxQDZcj2_jyTedtV2IoZvxs_mcqjqRVIO5Q36Q29PjwhQg-n1ARzEUkUo3lv3CU2aJhxMRzCf-Qg3YS2U16eMbMCahNJkt-NrEWibBcM40MsYuV6IbZ25gZE7n__4US-4X6Chw0-iCtUoF11ZuuxnKw3Cv7w9LfIW4DKKW_6aoCnp71ETb0uvzCtnUvvbHfGbLI84s_IdYv6vuB14VP8YvgdZjgOF9P79RYQcLvYCwLHLlv4PTvzw1O3h0Jpvn0m473c-dox12EwSHw.xaYvtClNm5JgKC8Ua7qn9A"


model = whisper.load_model("base", device='cpu')
model.device
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:04<00:00, 30.5MiB/s]
# device(type='cpu')

# %%
#Transcribe Function
def transcribe(audio):

    # load audio and pad/trim it to fit 30 seconds
    audio = whisper.load_audio(audio)
    audio = whisper.pad_or_trim(audio)

    # make log-Mel spectrogram and move to the same device as the model
    mel = whisper.log_mel_spectrogram(audio).to(model.device)

    # detect the spoken language
    _, probs = model.detect_language(mel)

    # decode the audio
    options = whisper.DecodingOptions()
    result = whisper.decode(model, mel, options)
    result_text = result.text

    # Pass the generated text to Audio
    chatgpt_api = ChatGPT(secret_token)
    resp = chatgpt_api.send_message(result_text)
    out_result = resp['message']

    return [result_text, out_result]

# %%
#Gradio Interface
output_1 = gr.Textbox(label="Speech to Text")
output_2 = gr.Textbox(label="ChatGPT Output")


gr.Interface(
    title = 'OpenAI Whisper and ChatGPT ASR Gradio Web UI',
    fn=transcribe,
    inputs=[
        gr.inputs.Audio(source="microphone", type="filepath")
    ],

    outputs=[
        output_1,  output_2
    ],
    live=True).launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
